# %%
import json

candidates = []

with open("../data/candidates.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        candidates.append(json.loads(line))

print("Total Candidates:", len(candidates))
# Out:
# Total Candidates: 100000

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.ranking_engine import RankingEngine

# %%
print(len(candidates))
# Out:
# 100000

# %%
from src.parser import Candidate

candidate = Candidate(candidates[0])

print(candidate.name)
print(candidate.experience)
# Out:
# Ira Vora
# 6.9

# %%
from src.skill_matcher import SkillMatcher

skill_matcher = SkillMatcher()

score = skill_matcher.calculate_skill_score(
    candidate.skills
)

print(score)
# Out:
# 0.21428571428571427

# %%
print(candidates[0].keys())
# Out:
# dict_keys(['candidate_id', 'profile', 'career_history', 'education', 'skills', 'certifications', 'languages', 'redrob_signals'])

# %%
print(candidates[0]["profile"])
# Out:
# {'anonymized_name': 'Ira Vora', 'headline': 'Backend Engineer | SQL, Spark, Cloud', 'summary': "Software / data professional with 6.9 years of experience building data pipelines, backend systems, and analytics infrastructure. I'm a backend/data hybrid — Spark, Airflow, SQL warehouses are home territory; I'm building competence on the ML side. My toolkit is solid on the data engineering side — Python, SQL, Spark, Airflow, warehouse design — and I've completed a couple of self-directed ML projects (Kaggle competitions, side projects fine-tuning small models). Interested in transitioning toward more AI/ML-focused work, ideally at a company where I can leverage my existing data-infra skills while learning modern ML practice.", 'location': 'Toronto', 'country': 'Canada', 'years_of_experience': 6.9, 'current_title': 'Backend Engineer', 'current_company': 'Mindtree', 'current_company_size': '10001+', 'current_industry': 'IT Services'}

# %%
print(candidates[0]["redrob_signals"])
# Out:
# {'profile_completeness_score': 86.9, 'signup_date': '2025-10-16', 'last_active_date': '2026-05-20', 'open_to_work_flag': True, 'profile_views_received_30d': 23, 'applications_submitted_30d': 2, 'recruiter_response_rate': 0.34, 'avg_response_time_hours': 177.8, 'skill_assessment_scores': {'NLP': 38.8, 'Image Classification': 64.8, 'Fine-tuning LLMs': 41.6, 'Speech Recognition': 53.7}, 'connection_count': 356, 'endorsements_received': 35, 'notice_period_days': 60, 'expected_salary_range_inr_lpa': {'min': 18.7, 'max': 36.1}, 'preferred_work_mode': 'onsite', 'willing_to_relocate': False, 'github_activity_score': 9.2, 'search_appearance_30d': 249, 'saved_by_recruiters_30d': 4, 'interview_completion_rate': 0.71, 'offer_acceptance_rate': 0.58, 'verified_email': True, 'verified_phone': True, 'linkedin_connected': False}

# %%
import sys
sys.path.append("..")

# %%
from src.parser import Candidate

# %%
candidate = Candidate(
    candidates[0]
)

# %%
print(candidate.name)

print(candidate.experience)

print(candidate.skills[:5])
# Out:
# Ira Vora
# 6.9
# ['Tailwind', 'NLP', 'Image Classification', 'Fine-tuning LLMs', 'Weights & Biases']

# %%
def get_candidate_text(self):

    skill_text = " ".join(
        self.skills
    )

    return f"""
    {self.summary}

    Skills:
    {skill_text}
    """

# %%
candidate.skills
# Out:
# ['Tailwind',
#  'NLP',
#  'Image Classification',
#  'Fine-tuning LLMs',
#  'Weights & Biases',
#  'Speech Recognition',
#  'Photoshop',
#  'TTS',
#  'LoRA',
#  'Apache Beam',
#  'AWS',
#  'Flask',
#  'BentoML',
#  'Milvus',
#  'GANs',
#  'Statistical Modeling',
#  'GCP']

# %%
from src.jd_processor import (
    load_job_description
)

# %%
jd = load_job_description(
    "../data/job_description.docx"
)

# %%
print(jd[:1000])
# Out:
# Job Description: Senior AI Engineer — Founding Team
# Company: Redrob AI (Series A AI-native talent intelligence platform)
# Location: Pune/Noida, India (Hybrid — flexible cadence) | Open to relocation candidates from Tier-1 Indian cities
# Employment Type: Full-time
# Experience Required: 5–9 years (see "what we mean by this" below)
#
# Let's be honest about this role
# We're going to write this JD differently from most. We're a Series A company that just raised our round and we're building a new AI Engineering org from scratch. This is the kind of role where the JD changes every six months because the company changes every six months. So instead of pretending we have a fixed checklist, we're going to tell you what we actually need and what we've gotten wrong before.
# If you've spent your career at Google or Meta and you want a well-scoped role with a defined ladder, this isn't it.
# ...

# %%
import sys

sys.path.append("..")

# %%
from src.semantic_matcher import (
    SemanticMatcher
)

# %%
matcher = SemanticMatcher()
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1504.26it/s]

# %%
import importlib
import src.parser

importlib.reload(src.parser)

from src.parser import Candidate

# %%
candidate = Candidate(
    candidates[0]
)

candidate_text = (
    candidate.get_candidate_text()
)

# %%
score = matcher.calculate_similarity(
    jd,
    candidate_text
)

print(score)
# Out:
# 0.5214989185333252

# %%
for i in range(5):

    candidate = Candidate(
        candidates[i]
    )

    score = matcher.calculate_similarity(
        jd,
        candidate.get_candidate_text()
    )

    print(
        candidate.id,
        round(score, 4)
    )
# Out:
# CAND_0000001 0.5215
# CAND_0000002 0.5611
# CAND_0000003 0.5767
# CAND_0000004 0.5593
# CAND_0000005 0.5475

# %%
import sys
import os

sys.path.append(
    os.path.abspath("..")
)

# %%
from src.skill_matcher import SkillMatcher

# %%
import os

print(os.getcwd())
# Out:
# c:\AI_Recruitment_System\notebooks

# %%
from src.parser import Candidate

# %%
from src.skill_matcher import (
    SkillMatcher
)

skill_matcher = SkillMatcher()

candidate = Candidate(
    candidates[0]
)

score = (
    skill_matcher
    .calculate_skill_score(
        candidate.skills
    )
)

print(score)
# Out:
# 0.21428571428571427

# %%
from src.ranking_engine import RankingEngine

ranker = RankingEngine()

# %%
score = ranker.calculate_final_score(
    semantic_score=0.65,
    skill_score=0.40,
    experience_score=1.0,
    behavioral_score=0.70,
    product_fit_score=0.60
)

print(score)
# Out:
# 0.6375

# %%
candidates[:100]
# Out:
# [{'candidate_id': 'CAND_0000001',
#   'profile': {'anonymized_name': 'Ira Vora',
#    'headline': 'Backend Engineer | SQL, Spark, Cloud',
#    'summary': "Software / data professional with 6.9 years of experience building data pipelines, backend systems, and analytics infrastructure. I'm a backend/data hybrid — Spark, Airflow, SQL warehouses are home territory; I'm building competence on the ML side. My toolkit is solid on the data engineering side — Python, SQL, Spark, Airflow, warehouse design — and I've completed a couple of self-directed ML projects (Kaggle competitions, side projects fine-tuning small models). Interested in transitioning toward more AI/ML-focused work, ideally at a company where I can leverage my existing data-infra skills while learning modern ML practice.",
#    'location': 'Toronto',
#    'country': 'Canada',
#    'years_of_experience': 6.9,
#    'current_title': 'Backend Engineer',
#    'current_company': 'Mindtree',
#    'current_company_size': '10001+',
# ...
